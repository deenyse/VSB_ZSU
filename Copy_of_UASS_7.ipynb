# %% [markdown]
# <a href="https://colab.research.google.com/github/deenyse/VSB_ZSU/blob/main/Copy_of_UASS_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ukázka generování sítě z XML dat

# %%
import xml.etree.ElementTree as ET
import networkx as nx
from collections import defaultdict
from datetime import datetime
from typing import List, Dict, Any


def parse_xml(filepath: str):
    tree = ET.parse(filepath)
    root = tree.getroot()

    accounts = {}
    for acc in root.find("Accounts"):
        addr = acc.attrib.get("smtpAddress")
        if addr:
            accounts[addr] = acc.attrib

    messages = []
    for msg in root.findall("Message"):
        sender = msg.attrib.get("Sender")
        sent_raw = msg.attrib.get("Sent")
        sent = datetime.fromisoformat(sent_raw.replace("Z", "+00:00")) if sent_raw else None

        recipients = [
            {"type": r.attrib.get("Type", "To"), "email": r.text.strip()}
            for r in msg.findall("Recipient") if r.text
        ]

        msg_data = {
            "sender": sender,
            "sent": sent,
            "recipients": recipients,
            "attributes": msg.attrib.copy()
        }
        messages.append(msg_data)

    return accounts, messages


def build_graph(accounts: Dict[str, Dict[str, str]], messages: List[Dict[str, Any]]) -> nx.DiGraph:
    G = nx.DiGraph()
    edge_weights = defaultdict(int)

    for addr, attrs in accounts.items():
        domain = addr.split("@")[-1] if addr else None
        G.add_node(addr, domain=domain, **attrs)

    for msg in messages:
        sender = msg["sender"]
        if sender not in accounts:
            continue

        sent = msg["sent"]
        msg_attrs = msg["attributes"]

        for rec in msg["recipients"]:
            recipient = rec["email"]
            edge_weights[(sender, recipient)] += 1

            if not G.has_edge(sender, recipient):
                G.add_edge(sender, recipient,
                           weight=1,
                           first_date=sent,
                           last_date=sent,
                           first_year=sent.year if sent else None,
                           last_year=sent.year if sent else None,
                           messages=[msg_attrs])
            else:
                edge = G[sender][recipient]
                edge["weight"] += 1
                edge["messages"].append(msg_attrs)

                if sent:
                    if "last_date" not in edge or sent > edge["last_date"]:
                        edge["last_date"] = sent
                        edge["last_year"] = sent.year
                    if "first_date" not in edge or sent < edge["first_date"]:
                        edge["first_date"] = sent
                        edge["first_year"] = sent.year

    return G

def create_email_ego_subgraph(G, ego_email: str, distance: int = 1) -> nx.DiGraph:
  # TODO: Doplnit export ego site pro zvoleny email https://networkx.org/documentation/stable/reference/generated/networkx.generators.ego.ego_graph.html
  return None

def export_graph(G: nx.DiGraph, path="email_network_weighted.gexf"):
    H = G.copy()
    for u, v, data in H.edges(data=True):
        if isinstance(data.get("messages"), list):
            data["message_count"] = len(data["messages"])
            del data["messages"]

        for k in ["first_date", "last_date"]:
            if isinstance(data.get(k), datetime):
                data[k] = data[k].isoformat()

    nx.write_gexf(H, path)
    print(f"Graph exported to {path}")

accounts, messages = parse_xml("teamnet_anonymized.xml")
G = build_graph(accounts, messages)

ego_net = create_email_ego_subgraph(G, "", 1)
export_graph(ego_net, "ego_network.gexf")

# %% [markdown]
# Výpis atributů

# %%
def print_node_attributes(G: nx.DiGraph, limit: [int] = 10):
    for i, (node, data) in enumerate(G.nodes(data=True)):
        print(f"{i+1}. {node}: {data}")
        if limit and i + 1 >= limit:
            break

print_node_attributes(G)

def print_edge_attributes(G: nx.DiGraph, limit: [int] = 10):
    for i, (u, v, data) in enumerate(G.edges(data=True)):
        print(f"{i+1}. {u} → {v}: {data}")
        if limit and i + 1 >= limit:
            break

print_edge_attributes(G)
# Out:
# 1. name00001@domain0001.com: {'domain': 'domain0001.com', 'smtpAddress': 'name00001@domain0001.com'}
# 2. name00002@domain0002.cz: {'domain': 'domain0002.cz', 'smtpAddress': 'name00002@domain0002.cz'}
# 3. name00003@domain0003.cz: {'domain': 'domain0003.cz', 'smtpAddress': 'name00003@domain0003.cz'}
# 4. name00004@domain0004.cz: {'domain': 'domain0004.cz', 'smtpAddress': 'name00004@domain0004.cz'}
# 5. name00005@domain0005.cz: {'domain': 'domain0005.cz', 'smtpAddress': 'name00005@domain0005.cz'}
# 6. name00006@domain0004.cz: {'domain': 'domain0004.cz', 'smtpAddress': 'name00006@domain0004.cz'}
# 7. name00007@domain0004.cz: {'domain': 'domain0004.cz', 'smtpAddress': 'name00007@domain0004.cz'}
# 8. name00008@domain0004.cz: {'domain': 'domain0004.cz', 'smtpAddress': 'name00008@domain0004.cz'}
# 9. name00009@domain0004.cz: {'domain': 'domain0004.cz', 'smtpAddress': 'name00009@domain0004.cz'}
# 10. name00010@domain0004.cz: {'domain': 'domain0004.cz', 'smtpAddress': 'name00010@domain0004.cz'}
# 1. name00001@domain0001.com → name00001@domain0001.com: {'weight': 47, 'first_date': datetime.datetime(2010, 2, 13, 11, 53, 31, tzinfo=datetime.timezone.utc), 'last_date': datetime.datetime(2015, 1, 1, 15, 59, 22, tzinfo=datetime.timezone.utc), 'first_year': 2010, 'last_year': 2015, 'messages': [{'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-16T19:46:37.000Z', 'MessageId': 'a9f28ad3-1fe5-4948-8fff-02311a39963c', 'Subject': 'term01243 term01244 term01245 term01246 term00931 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-12-04T12:54:31.000Z', 'MessageId': 'e21ffac7-387a-415c-99ad-3b040198a44b', 'Subject': 'term01243 term01244 term01245 term01332 term01333 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-12-04T12:54:31.000Z', 'MessageId': '01f88e6e-8ea9-4336-8475-25a62166a9a9', 'Subject': 'term01243 term01244 term01245 term01332 term01333 term01334 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-12-15T09:42:44.000Z', 'MessageId': '9cb3d760-518d-4835-876b-25c91cf14ce0', 'Subject': 'term01243 term01244 term01245 term01332 term01333 term01334 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-12-15T11:11:53.000Z', 'MessageId': 'bfdedb6e-5323-4b75-9320-338a659e85ac', 'Subject': 'term01243 term01244 term01245 term01246 term00166 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-12-15T11:12:35.000Z', 'MessageId': 'b48a2a08-0111-4afd-b20f-3cf813c9dae5', 'Subject': 'term01243 term01244 term01245 term01246 term00166 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-02-01T14:24:02.000Z', 'MessageId': 'f83ffc6d-5434-4fee-8736-b7719aed8a23', 'Subject': 'term01243 term01244 term01245 term00089 term01334 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-03-04T08:29:36.000Z', 'MessageId': '996332dc-343e-48b9-a2ea-f74c5177d9e1', 'Subject': 'term00629 term01773 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-09-06T19:11:31.000Z', 'MessageId': 'a9c53e99-87e0-4ba8-8855-376d3af8695d', 'Subject': 'term03905 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-07-20T16:34:06.000Z', 'MessageId': 'add062af-205c-4cbe-b9a0-87d18f4cdb4b'}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-04-10T19:34:35.000Z', 'MessageId': '3fddb850-7099-4f68-9b99-dd41576b25ac', 'Subject': 'term00232 term03908 term03908 term03909 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-04-08T18:15:51.000Z', 'MessageId': 'd4ba7cd5-da34-4cc3-a5cf-d9872f10b870', 'Subject': 'term01820 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-02-22T21:09:55.000Z', 'MessageId': '7d71b596-af11-4216-aa69-8fcc01e3f0ca'}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-02-22T20:58:03.000Z', 'MessageId': '260e111b-77f2-40fc-8f36-cec0f07c09f6', 'Subject': 'term00199 term03911 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-09-01T13:51:28.000Z', 'MessageId': 'db856efc-55b9-40d7-9fc5-a910aa74ac29', 'Subject': 'term03912 term01937 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-02-13T15:53:02.000Z', 'MessageId': '3a7756f2-ca51-4002-990e-39e399b77ab0', 'Subject': 'term00232 term03913 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-02-28T10:12:19.000Z', 'MessageId': 'a994e297-9bfd-4f5e-a8f9-264deae08368'}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-08-28T13:02:56.000Z', 'MessageId': 'cceb922a-5087-4565-8238-1cd0369bb271', 'Subject': 'term00463 term00218 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-08-11T16:57:16.000Z', 'MessageId': '1290b675-b30c-4a3e-bfb2-55f14bef468b', 'Subject': 'term00232 term03915 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-03-29T07:57:53.000Z', 'MessageId': '8d15ea5f-c1e6-4939-ad13-023c20092091', 'Subject': 'term01145 term01032 term03916 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-02-13T11:53:31.000Z', 'MessageId': '3c4eee6a-6525-44a9-a43e-3efacc8e78c7', 'Subject': 'term00674 term03907 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-06-10T00:14:47.000Z', 'MessageId': '427ea524-b5c4-4cc2-a7d0-ce4c3471cec ...
# 2. name00001@domain0001.com → name01094@domain0001.com: {'weight': 1, 'first_date': datetime.datetime(2010, 12, 15, 9, 42, 43, tzinfo=datetime.timezone.utc), 'last_date': datetime.datetime(2010, 12, 15, 9, 42, 43, tzinfo=datetime.timezone.utc), 'first_year': 2010, 'last_year': 2010, 'messages': [{'Sender': 'name00001@domain0001.com', 'Sent': '2010-12-15T09:42:43.000Z', 'MessageId': '931a924d-4329-4832-a24f-602cf6630d43', 'Subject': 'term01243 term01244 term01245 term01332 term01333 '}]}
# 3. name00001@domain0001.com → name01089@domain0001.com: {'weight': 1, 'first_date': datetime.datetime(2011, 2, 1, 14, 24, 1, tzinfo=datetime.timezone.utc), 'last_date': datetime.datetime(2011, 2, 1, 14, 24, 1, tzinfo=datetime.timezone.utc), 'first_year': 2011, 'last_year': 2011, 'messages': [{'Sender': 'name00001@domain0001.com', 'Sent': '2011-02-01T14:24:01.000Z', 'MessageId': '41af6ccd-8acd-46c4-825b-81d8d234c61b', 'Subject': 'term01243 term01244 term01245 term00089 '}]}
# 4. name00001@domain0001.com → name00077@domain0002.cz: {'weight': 2, 'first_date': datetime.datetime(2010, 3, 4, 9, 12, 54, tzinfo=datetime.timezone.utc), 'last_date': datetime.datetime(2010, 3, 4, 9, 24, 31, tzinfo=datetime.timezone.utc), 'first_year': 2010, 'last_year': 2010, 'messages': [{'Sender': 'name00001@domain0001.com', 'Sent': '2010-03-04T09:12:54.000Z', 'MessageId': 'aa98e072-1c74-4a89-9cdb-87fc99568a38'}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-03-04T09:24:31.000Z', 'MessageId': 'b338c9d3-bfcc-4c41-ab9c-5df762da6391', 'Subject': 'term00208 '}]}
# 5. name00001@domain0001.com → name00810@domain0005.cz: {'weight': 39, 'first_date': datetime.datetime(2010, 5, 31, 19, 40, 6, tzinfo=datetime.timezone.utc), 'last_date': datetime.datetime(2014, 4, 1, 6, 45, 59, tzinfo=datetime.timezone.utc), 'first_year': 2010, 'last_year': 2014, 'messages': [{'Sender': 'name00001@domain0001.com', 'Sent': '2010-05-31T19:40:06.000Z', 'MessageId': '1cfe29b6-4970-4d89-a272-7ecd34adacf0', 'Subject': 'term03906 term00621 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2012-09-04T14:54:23.000Z', 'MessageId': '524eb5a9-0cef-49c6-8542-68af121f7330', 'InReplyTo': '802439a3-b538-4130-8e74-6323f5e02b91', 'Subject': 'term03980 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-11-28T15:12:51.000Z', 'MessageId': 'e34f96dc-a958-4247-b330-5a39c9e117c9', 'Subject': 'term01032 term04378 term04379 term09186 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-12-06T12:59:58.000Z', 'MessageId': '5f126c1e-33d3-4794-a61f-15874c28c2c3', 'InReplyTo': 'ebc3f55c-70f6-43a3-b90c-b88afe30bad6', 'Subject': 'term01032 term04378 term04379 term09186 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-12-15T13:33:47.000Z', 'MessageId': '06bccb64-6777-47da-8818-7c1ef0f5adac', 'InReplyTo': 'bde36a5c-f1b0-4975-a657-12b50317255f', 'Subject': 'term01032 term04378 term04379 term09186 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-10T12:41:59.000Z', 'MessageId': '6852e5d3-daf3-4902-805f-28b7f4e27347', 'InReplyTo': '303f79a9-a2ca-4333-99f8-945dec8ad3cb', 'Subject': 'term01032 term04378 term04379 term09186 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-11T06:29:56.000Z', 'MessageId': 'b319d81e-6699-4ea5-8258-3bee82278756', 'InReplyTo': '303f79a9-a2ca-4333-99f8-945dec8ad3cb', 'Subject': 'term01032 term04378 term04379 term09186 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-11T06:52:04.000Z', 'MessageId': '2863fb74-e74d-47f9-b441-400c2e8a06d7', 'InReplyTo': 'c6c25a65-da87-4650-88b3-6cbd14095662', 'Subject': 'term01032 term04378 term04379 term09186 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-12T23:46:03.000Z', 'MessageId': 'f2239e7d-232f-4899-ad5d-57b06f09f817', 'Subject': 'term01032 term04378 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-13T08:20:40.000Z', 'MessageId': '8479ad93-8559-420e-b3bf-c5eb2a787a86', 'InReplyTo': '1bf38f0f-fe66-45ab-a11d-2e5900df2b04', 'Subject': 'term01032 term04378 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-09-06T13:43:00.000Z', 'MessageId': '265e7b00-f12b-4334-92de-8897d6fd54f7', 'Subject': 'term02196 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-10-20T10:42:10.000Z', 'MessageId': '3977247f-eb9f-46d9-b522-c5bd7c23d0d6', 'Subject': 'term02164 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-10-21T07:45:59.000Z', 'MessageId': '00ed0f3e-5892-423c-b98b-252cbd0b229f', 'InReplyTo': '5fb64d70-58c5-4f77-aed8-0e2a560c14da', 'Subject': 'term02164 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2012-01-11T12:08:26.000Z', 'MessageId': '04028ca3-0975-439c-83d0-6eaf9e5ec34b', 'InReplyTo': '3a44075a-e86f-4471-a678-44305b6fbc2e', 'Subject': 'term00722 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2012-01-16T21:47:50.000Z', 'MessageId': '54d8cd77-d3f1-4857-8315-2fec33672677', 'InReplyTo': 'fe5f2e3f-dabf-4b78-96f2-996644111fdf', 'Subject': 'term00489 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2012-01-19T06:22:11.000Z', 'MessageId': 'c6e92d44-3afc-40c9-8e99-172b144c4f4b', 'InReplyTo': 'fe5f2e3f-dabf-4b78-96f2-996644111fdf', 'Subject': 'term00489 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2012-05-02T19:24:20.000Z', 'MessageId': '86efdf66-899b-4f9c-a90b-daa048a68489', 'InReplyTo': 'e6464b6e-10a7-4b9e-950f-ae1c6bfd9d2a', 'Subject': 'term09422 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2012-12-12T16:23:39.000Z', 'MessageId': '7d3501c2-9f87-4776-b467-16888e45eb51', 'InReplyTo': 'bf79a14e-cdac-4767-aa8d-56af359afdda', 'Subject': 'term09286 '}, {'Sender': 'name00001@domain0001.co ...
# 6. name00001@domain0001.com → name00540@domain0005.cz: {'weight': 3, 'first_date': datetime.datetime(2010, 5, 31, 19, 40, 6, tzinfo=datetime.timezone.utc), 'last_date': datetime.datetime(2011, 8, 26, 10, 29, 53, tzinfo=datetime.timezone.utc), 'first_year': 2010, 'last_year': 2011, 'messages': [{'Sender': 'name00001@domain0001.com', 'Sent': '2010-05-31T19:40:06.000Z', 'MessageId': '1cfe29b6-4970-4d89-a272-7ecd34adacf0', 'Subject': 'term03906 term00621 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-04T07:55:51.000Z', 'MessageId': '2e13b342-c032-4ef4-9da6-6673e54d30cf', 'InReplyTo': '67e1b843-d57b-48f4-afc7-8537148be681', 'Subject': ''}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-08-26T10:29:53.000Z', 'MessageId': 'b1aff29c-a27c-464f-a793-0bb8cc7e2d40', 'InReplyTo': '1d9309be-6d0d-4aa0-92ed-46478f8973bf', 'Subject': 'term01890 '}]}
# 7. name00001@domain0001.com → name02520@domain0005.cz: {'weight': 1, 'first_date': datetime.datetime(2010, 4, 8, 8, 0, 30, tzinfo=datetime.timezone.utc), 'last_date': datetime.datetime(2010, 4, 8, 8, 0, 30, tzinfo=datetime.timezone.utc), 'first_year': 2010, 'last_year': 2010, 'messages': [{'Sender': 'name00001@domain0001.com', 'Sent': '2010-04-08T08:00:30.000Z', 'MessageId': 'b73d3b73-e88f-4b91-8f3a-fd23a2397ad6', 'InReplyTo': '5ba6acbe-352a-44e8-8475-93e0431ad4d4', 'Subject': 'term00674 '}]}
# 8. name00001@domain0001.com → name00625@domain0051.cz: {'weight': 109, 'first_date': datetime.datetime(2010, 3, 5, 19, 23, 53, tzinfo=datetime.timezone.utc), 'last_date': datetime.datetime(2014, 11, 27, 11, 18, 13, tzinfo=datetime.timezone.utc), 'first_year': 2010, 'last_year': 2014, 'messages': [{'Sender': 'name00001@domain0001.com', 'Sent': '2010-03-05T19:23:53.000Z', 'MessageId': 'c581fc97-5012-48b1-8a6f-9c7f7e1f3d9b', 'Subject': 'term03914 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-08-18T06:06:09.000Z', 'MessageId': 'a767c3ce-aa22-4744-96d5-73491602c912', 'Subject': 'term00232 term07624 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-05T18:35:30.000Z', 'MessageId': '081cee99-1dae-4940-a061-4ad40c4c1b41', 'Subject': 'term09162 term09163 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-08T09:05:22.000Z', 'MessageId': '799d553f-5aa3-44a0-991e-f4aabf54d918', 'Subject': 'term04404 term09165 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-31T08:24:42.000Z', 'MessageId': '4f30fbf5-5a28-4027-a09e-bf5437c9f00e', 'Subject': 'term01145 term09170 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-11-14T10:47:33.000Z', 'MessageId': '3624df75-cfaa-4fcb-bbb5-768890fd4620', 'Subject': 'term00232 term07624 term00438 term07624 term00438 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-11-30T17:21:17.000Z', 'MessageId': '06fdafbb-92dc-4e73-a85b-9a6b93cf3169', 'Subject': 'term00232 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-06T19:13:20.000Z', 'MessageId': 'b77f89de-5d93-4a84-8c7b-ae8c536e3d02', 'InReplyTo': 'e8c94d71-6d5c-4188-aeae-65b708777193', 'Subject': 'term01418 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-18T21:01:13.000Z', 'MessageId': '9cca7d64-8ce5-4800-8e65-9ef41c882920', 'Subject': 'term03324 term03373 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-02-09T09:53:49.000Z', 'MessageId': '8ec30b87-4162-4622-bf36-1d5bc54b4cdd', 'Subject': 'term00727 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-02-10T07:42:07.000Z', 'MessageId': '0b914bef-a59e-48fb-b4ae-10e197697dd7', 'Subject': ''}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-04-29T11:42:21.000Z', 'MessageId': '87b870a7-470b-4be7-bbe8-5e09d54c5650', 'Subject': 'term01428 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-05-09T13:54:42.000Z', 'MessageId': '0abf7404-8198-49f4-9eb7-8c8625c5e004', 'Subject': ''}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-05-16T07:51:05.000Z', 'MessageId': 'ae7db260-54fb-4b19-a2bb-ff07298a9760', 'Subject': ''}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-06-10T13:48:58.000Z', 'MessageId': 'ea86eb2c-d591-4f7f-bedc-fc7b02733c3e', 'Subject': ''}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-07-27T13:37:50.000Z', 'MessageId': 'e3a8b58a-a936-4342-8e59-cb2b601f41a0', 'Subject': 'term09300 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-08-06T07:24:31.000Z', 'MessageId': '0637b903-66c0-4008-8b54-6b9a4c6085ae', 'Subject': 'term01016 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-08-15T12:20:25.000Z', 'MessageId': '49ae6d97-b882-42d7-ae1b-b7aca635250e', 'Subject': 'term09306 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-08-30T21:55:29.000Z', 'MessageId': '9f4b3627-66a0-4a19-9181-57bd42b595d0', 'Subject': 'term09313 term09314 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-10-04T17:45:27.000Z', 'MessageId': 'af89f44a-acff-4e3d-8455-6874c4b7313b', 'Subject': 'term00766 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-10-06T16:42:08.000Z', 'MessageId': 'bccd1aa1-c94d-4189-999e-9d9f1db6f431', 'Subject': 'term00955 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-10-12T15:56:44.000Z', 'MessageId': '140fa951-59df-4ef5-9593-fbd5813aab67', 'Subject': 'term01878 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-10-31T18:44:18.000Z', 'MessageId': '9ff9614a-3d57-4fca-a6fa-10c06f172ee6', 'Subject': 'term04287 '}, {'Sender': 'name00001@domain0001.com', 'Sent':  ...
# 9. name00001@domain0001.com → name00689@domain0004.cz: {'weight': 327, 'first_date': datetime.datetime(2010, 2, 10, 20, 3, 10, tzinfo=datetime.timezone.utc), 'last_date': datetime.datetime(2014, 4, 24, 13, 26, 6, tzinfo=datetime.timezone.utc), 'first_year': 2010, 'last_year': 2014, 'messages': [{'Sender': 'name00001@domain0001.com', 'Sent': '2010-12-16T13:10:01.000Z', 'MessageId': '4a9b2ea2-6d28-480c-8514-a3a309323c7b', 'Subject': 'term01357 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-12-27T19:51:01.000Z', 'MessageId': 'a1df6b4e-23e0-4da6-a611-47c95f3c88e1', 'Subject': 'term03921 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-09-01T08:35:05.000Z', 'MessageId': '134cada7-81f0-406d-8daf-bc9f0d373d25', 'Subject': 'term00626 term00627 term00628 term00699 term00753 term00629 term00697 term00698 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-09-07T08:31:34.000Z', 'MessageId': '534ee78a-2766-425d-b1e4-089751dfb1cb', 'Subject': 'term00723 term00724 term00725 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-09-07T12:40:29.000Z', 'MessageId': '3d994331-176f-4164-b31a-418b00d5e303', 'Subject': 'term00734 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-09-08T21:09:19.000Z', 'MessageId': '8c19ba96-8575-45f4-98d6-ed96dd553b04', 'Subject': 'term00742 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-09-08T22:51:41.000Z', 'MessageId': '6e4a00bd-adc3-45aa-b150-9913f671b1bd', 'Subject': 'term00742 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-09-27T04:32:55.000Z', 'MessageId': 'd4cacdfc-a30d-482b-98c4-9da8234eb0ce'}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-09-27T16:58:01.000Z', 'MessageId': 'a610fbe6-bdae-4f95-85b8-2e6da17e69ae', 'InReplyTo': '50edbdf7-ceb4-4601-8342-70044fcf641f', 'Subject': 'term01161 term01162 term00061 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-09-28T12:26:33.000Z', 'MessageId': '0405110f-0b4c-4126-a884-8ecdfe2607e9', 'InReplyTo': '658ac149-bf0e-4593-aa0e-fd08dfab3a4f', 'Subject': 'term00722 term00465 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-01T19:09:09.000Z', 'MessageId': '1a467558-8600-4a93-979e-4bcb01188054', 'Subject': 'term00722 term01062 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-06T20:14:03.000Z', 'MessageId': 'dc0c6153-7895-4f23-baf8-757e39bfd941', 'InReplyTo': 'bdc11a72-8457-4529-a505-a0a9c730450b', 'Subject': 'term00715 term00716 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-07T08:41:25.000Z', 'MessageId': 'd6fd8ec2-71db-4a44-ab5e-06e46d23f0eb', 'Subject': 'term00711 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-08T06:28:46.000Z', 'MessageId': '20ee0f6f-fac3-4db2-a228-36f579f40e93', 'Subject': 'term09164 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-15T06:29:23.000Z', 'MessageId': '66adf457-3ec9-477c-945b-61962c03d1ae', 'InReplyTo': '829639eb-d116-4eb3-9d72-56bb75c40c8a', 'Subject': 'term00057 term00815 term00815 term01114 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-18T21:02:18.000Z', 'MessageId': '038d631a-bf2e-4a90-b137-47a303ab8054', 'Subject': 'term01252 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-18T22:58:19.000Z', 'MessageId': '2af73b6d-c3b0-49ce-9d1d-0df565ff9ba0', 'Subject': 'term00722 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-23T07:00:20.000Z', 'MessageId': 'ddfc553a-61b9-41d7-8102-25ea0073cc6d', 'Subject': 'term01259 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-23T07:30:14.000Z', 'MessageId': 'db30fac2-373c-435f-b16d-c2e728cdf5b8', 'Subject': 'term00551 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-27T06:19:16.000Z', 'MessageId': '952aa9a5-853a-4d13-90cc-c62967b0b658', 'InReplyTo': '2ce3167c-aac7-44fa-929a-025dfd4a52f5', 'Subject': 'term01261 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-29T08:35:37.000Z', 'MessageId': '6c44bca8-4893-4f11-915f-a5b31c03dc86'}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-11-02T21:59:25.000Z', 'MessageId ...
# 10. name00001@domain0001.com → name00009@domain0004.cz: {'weight': 45, 'first_date': datetime.datetime(2010, 10, 6, 20, 14, 3, tzinfo=datetime.timezone.utc), 'last_date': datetime.datetime(2014, 12, 6, 7, 8, 39, tzinfo=datetime.timezone.utc), 'first_year': 2010, 'last_year': 2014, 'messages': [{'Sender': 'name00001@domain0001.com', 'Sent': '2010-12-16T13:10:01.000Z', 'MessageId': '4a9b2ea2-6d28-480c-8514-a3a309323c7b', 'Subject': 'term01357 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2013-04-18T14:59:42.000Z', 'MessageId': '6c720983-7091-4907-b5e6-bac99a6e08e9', 'InReplyTo': 'c0c1102d-ba9c-4142-918d-1b9fbea1bab9', 'Subject': 'term04058 term01719 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-10-06T20:14:03.000Z', 'MessageId': 'dc0c6153-7895-4f23-baf8-757e39bfd941', 'InReplyTo': 'bdc11a72-8457-4529-a505-a0a9c730450b', 'Subject': 'term00715 term00716 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-12-24T07:02:26.000Z', 'MessageId': '0b873550-e3e4-4fec-8888-31055ba2553e', 'Subject': 'term01407 term01042 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2010-12-26T19:13:46.000Z', 'MessageId': '9aa81af7-6116-4d8a-9913-b3a9840f7f19', 'InReplyTo': '6e954b5d-e6c1-4d57-bd05-3d00dce85e2f', 'Subject': 'term01407 term01042 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-03T11:47:03.000Z', 'MessageId': '1d4c7fcf-52b8-4286-819a-a3a408cdc421', 'Subject': 'term00474 term01411 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-03T19:29:03.000Z', 'MessageId': '8a9cc5c2-2fa1-42f5-94e2-ff3c23afaae5', 'InReplyTo': '33ffb112-0e6d-43f6-92fd-4b93608562a8', 'Subject': ''}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-10T14:40:10.000Z', 'MessageId': '0824dd78-d818-45f3-a0e3-f3b1c6da1b17', 'Subject': 'term02868 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-11T08:39:42.000Z', 'MessageId': '0eb00cc8-78b5-443c-9f53-de2c91338a4f', 'Subject': 'term00711 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-11T08:57:27.000Z', 'MessageId': 'b8a177b7-cbb2-4894-860d-ece49e45ef66', 'InReplyTo': 'f34a61a7-5f8d-43e3-a46d-e377a33e5404', 'Subject': 'term01421 term00876 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-13T08:56:41.000Z', 'MessageId': '70c47a34-c459-4d13-b34f-7d61f086a71f', 'Subject': 'term00711 term01426 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-01-13T11:07:46.000Z', 'MessageId': 'f34a4a1d-647b-4595-ad0d-5435b2629a0e', 'Subject': 'term09199 term00084 term00218 term00489 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-02-03T06:50:04.000Z', 'MessageId': '17f9d619-6f9e-47ce-b178-caf41f9720e1', 'Subject': 'term01042 term00227 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-02-10T13:29:55.000Z', 'MessageId': '43da28cc-f7e0-42cb-af1e-c2dfa456325b', 'Subject': 'term00711 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-09-27T10:51:50.000Z', 'MessageId': '37db0c38-46e7-411c-aa22-d263b7605177', 'Subject': 'term01337 term02288 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-10-18T10:01:41.000Z', 'MessageId': '5187fe2f-5885-4f11-ad17-d6115f1198dc', 'Subject': 'term01870 term01470 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-11-14T12:34:17.000Z', 'MessageId': '68b52ea2-dd45-44b4-9e01-d67df60b494a'}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-11-17T10:35:28.000Z', 'MessageId': '4b4ee0c0-3596-4651-8ab4-4a02ce6a4ba0', 'InReplyTo': '84e0aae0-531d-472e-b19f-2ca6417947f3', 'Subject': 'term01907 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-11-17T15:14:26.000Z', 'MessageId': 'bbb440c3-ef11-4942-a688-a0f29effef81', 'InReplyTo': '5937fc69-d125-4c43-8707-242d6f495188', 'Subject': 'term01907 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-11-18T13:26:12.000Z', 'MessageId': 'd9247de2-a2bb-4cad-9b98-1fce32395326', 'InReplyTo': '824819e9-3884-4e45-8178-e1accc5345fd', 'Subject': 'term01907 '}, {'Sender': 'name00001@domain0001.com', 'Sent': '2011-11-18T14:04:43.000Z', 'MessageId': '0845e3bf-ffed-442 ...

# %% [markdown]
# Ukázka jak vyfiltrovat vrcholy a hrany podle parametru

# %%
nodes = []
x = 3
attr = ''
for n, data in G.nodes(data=True):
    if data.get(attr) is not None and data[attr] >= x:
        nodes.append(n)

edges = []
y = 1
for s, t, data in G.edges(data=True):
    if data.get("weight") is not None and data["weight"] >= y:
        edges.append((s, t))

H = nx.Graph()
for n in nodes:
    H.add_node(n, **G.nodes[n])

for s, t in edges:
    if s in H and t in H:
        H.add_edge(s, t, **G[s][t])

def create_x(G, atrributes, distance:int = 1):
  # TODO: Zpracovat maily pouze z malého časového období (1 rok/měsíc)
  # Seznam domén a vzít úvahu pouze maily, kde je odesílatelem někdo z domény v tomto seznamu.
  pass
